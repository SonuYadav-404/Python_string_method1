# %%
string = "This is python class"

# %% [markdown]
# # string.capitalize()

# %%
string =  "this is python class"
string.capitalize()
# Out:
# 'This is python class'

# %% [markdown]
# # string.casefold()

# %%
string.casefold()
# Out:
# 'this is python class'

# %% [markdown]
# # string.center()

# %%
string.center(3)
# Out:
# 'this is python class'

# %% [markdown]
# # string.count()

# %%
string.count("i")
# Out:
# 2

# %% [markdown]
# # string.encode()

# %%
string.encode()
# Out:
# b'this is python class'

# %% [markdown]
#  # string.endswith()

# %%
string.endswith("c")
# Out:
# False

# %% [markdown]
# # string.expandtabs()

# %%
string.expandtabs(55)
# Out:
# 'this is python class'

# %% [markdown]
#  # string.find()

# %%
string.find("s")
# Out:
# 3

# %% [markdown]
# # string.format()

# %%
string = "My name is {}"
string.format( "Sonu Yadav")
# Out:
# 'My name is Sonu Yadav'

# %% [markdown]
#  # string.format_map()

# %%
dict1 = {"city": "Delhi", "country": "India"}

string = "I live in {city}, {country}"
string.format_map(dict1)
# Out:
# 'I live in Delhi, India'

# %% [markdown]
# # string.index()

# %%
string.index("s")
# Out:
# 3

# %% [markdown]
# # string.isalnum()

# %%
string.isalnum()
# Out:
# False

# %% [markdown]
# # string.isalpha()

# %%
string.isalpha()
# Out:
# False

# %% [markdown]
# # string.isascii()

# %%
string.isascii()
# Out:
# True

# %% [markdown]
# # string.isdecimal()

# %%
string.isdecimal()
# Out:
# False

# %% [markdown]
# # string.isdigit()

# %%
string.isdigit()
# Out:
# False

# %% [markdown]
# # string.isidentifier()

# %%
string.isidentifier()
# Out:
# False

# %% [markdown]
# # string.islower()

# %%
string.islower()
# Out:
# True

# %% [markdown]
# # string.isnumeric()

# %%
string.isnumeric()
# Out:
# False

# %% [markdown]
# # string.isprintable()

# %%
string.isprintable()
# Out:
# True

# %% [markdown]
# # string.isspace()

# %%
string.isspace()
# Out:
# False

# %% [markdown]
# # string.istitle()

# %%
string.istitle()
# Out:
# False

# %% [markdown]
# # string.isupper()

# %%
string.isupper()
# Out:
# False

# %% [markdown]
# # string.join()

# %%
words = ["Hello", "World", "Python"]

result = " ".join(words)
print(result)
# Out:
# Hello World Python

# %% [markdown]
# # string.append()

# %%
string.append(1)

# %% [markdown]
# # string.clear()

# %%
string.clear()

# %% [markdown]
# # string.copy()

# %%
string.copy()
# Out:
# []

# %% [markdown]
# # string.count()

# %%
string.count(string)
# Out:
# 1

# %% [markdown]
# # string.ljust()

# %%
string.ljust(3)
# Out:
# 'This is python class'

# %% [markdown]
# # string.lower()

# %%
string.lower()
# Out:
# 'this is python class'

# %% [markdown]
# # string.lstrip()

# %%
string.lstrip()
# Out:
# 'This is python class'

# %% [markdown]
# # string.maketrans()

# %%
string.maketrans("This","java")
# Out:
# {84: 106, 104: 97, 105: 118, 115: 97}

# %% [markdown]
# # string.partition()

# %%
string.partition("hlw" "sonu")
# Out:
# ('This is python class', '', '')

# %% [markdown]
# # string.removeprefix()

# %%
string.removeprefix("T")
# Out:
# 'his is python class'

# %% [markdown]
# # string.removesuffix()

# %%
string.removesuffix("ss")
# Out:
# 'This is python cla'

# %% [markdown]
# # string.replace()

# %%
string.replace("This","That")
# Out:
# 'That is python class'

# %% [markdown]
# # string.rfind()

# %%
string.rfind("s")
# Out:
# 19

# %% [markdown]
# # string.rindex()

# %%
string.rindex("s")
# Out:
# 19

# %% [markdown]
# # string.rjust()

# %%
string.rjust(10)
# Out:
# 'This is python class'

# %% [markdown]
# # string.rpartition()

# %%
string.rpartition("T")
# Out:
# ('', 'T', 'his is python class')

# %% [markdown]
# # string.rsplit()

# %%
string.rsplit()
# Out:
# ['This', 'is', 'python', 'class']

# %% [markdown]
# # string.rstrip()

# %%
string.rstrip()
# Out:
# 'This is python class'

# %% [markdown]
# # string.split()

# %%
string.split()
# Out:
# ['This', 'is', 'python', 'class']

# %% [markdown]
# # string.splitlines()

# %%
string.splitlines()
# Out:
# ['This is python class']

# %% [markdown]
# # string.startswith()

# %%
string.startswith("This")
# Out:
# True

# %% [markdown]
# # string.strip()

# %%
string.strip("")
# Out:
# 'This is python class'

# %% [markdown]
# # string.swapcase()

# %%
string.swapcase()
# Out:
# 'tHIS IS PYTHON CLASS'

# %% [markdown]
# # string.title()

# %%
string.title()
# Out:
# 'This Is Python Class'

# %% [markdown]
# # string.translate()

# %%
string.translate("hello")
# Out:
# 'This is python class'

# %% [markdown]
# # string.upper()

# %%
string.upper()
# Out:
# 'THIS IS PYTHON CLASS'

# %% [markdown]
# # string.zfill()

# %%
string.zfill(3)
# Out:
# 'This is python class'
